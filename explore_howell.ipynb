# %%
import os
import pandas as pd

fn = os.path.join("data", "master_data_07142019_a.dta")
df = pd.read_stata(fn)

print(len(df))
print(df.columns)
# Out:
# 1520
# Index(['token_name', 'emps_li_0719', 'emps_web_0719',
#        'github_mainrep_commits_0719', 'github_date_last_commit_0719',
#        'github_repositories_0719', 'github_mainrep_branches_0719',
#        'github_mainrep_releases_0719', 'github_mainrep_contributors_0719',
#        'emps_0719',
#        ...
#        'github_br_delta', 'github_cont_delta', 'github_rel_delta',
#        'github_rep_delta', 'github_commits_delta', 'high_price_1',
#        'high_btc_price', 'med_btc_price', 'low_btc_price', 'raised_usd_bill'],
#       dtype='object', length=310)

# %%
df.head()
# Out:
#      token_name  emps_li_0719  emps_web_0719  github_mainrep_commits_0719  \
# 0      Gamecoin           NaN            NaN                          NaN
# 1         DIMND           1.0            NaN                          7.0
# 2         Grain           9.0           15.0                          NaN
# 3     MacroCoin           NaN            NaN                          7.0
# 4  MaidSafeCoin          43.0           34.0                       2170.0
#
#   github_date_last_commit_0719  github_repositories_0719  \
# 0                          NaT                       NaN
# 1                   2019-03-28                       1.0
# 2                          NaT                       NaN
# 3                   2014-02-08                       1.0
# 4                   2019-05-28                      51.0
#
#    github_mainrep_branches_0719  github_mainrep_releases_0719  \
# 0                           NaN                           NaN
# ...

# %%
# Creates a zip folder called out which has the dta file as a csv which can be used in RapidMiner if you wish to use it.
compression_opts = dict(method='zip', archive_name='out.csv')
df.to_csv('out.zip', index=False, compression=compression_opts)

# %%
df.head(10)
# Out:
#           token_name  emps_li_0719  emps_web_0719  \
# 0           Gamecoin           NaN            NaN
# 1              DIMND           1.0            NaN
# 2              Grain           9.0           15.0
# 3          MacroCoin           NaN            NaN
# 4       MaidSafeCoin          43.0           34.0
# 5       Legends Room           NaN            NaN
# 6           ApexCoin          22.0            NaN
# 7  Internet of Coins           4.0           22.0
# 8            Storj-x          56.0           63.0
# 9        FoldingCoin           3.0           11.0
#
#    github_mainrep_commits_0719 github_date_last_commit_0719  \
# 0                          NaN                          NaT
# 1                          7.0                   2019-03-28
# 2                          NaN                          NaT
# 3                          7.0                   2014-02-08
# 4                       2170.0                   2019-05-28
# ...
