# %% [markdown]
# Find top 100 coins listed on https://coinmarketcap.com/

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
from os import listdir
import re


headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
    }

url = "https://coinmarketcap.com"
req = requests.get(url, headers)
soup = BeautifulSoup(req.content, 'html.parser')
rows = soup.find_all("tr")
top_currencies = []
for index, row in enumerate(rows[1:]):
    top_currencies.append(url + row.find("a", href=True)["href"])

# %%
# get set of existing cells
path = "../data/whitepapers/coinmarketcap/"
existing_coins = set([re.sub("_[0-9]+","", f.split(".")[0].lower()) for f in listdir(path)])
print(sorted(existing_coins))
# Out:
# ['aave', 'avalanche', 'axie_infinity', 'bitcoin', 'bnb', 'cardano_ada', 'chainlink', 'cosmos', 'dai', 'decentraland', 'dogecoin', 'elrond', 'eos', 'ethereum', 'filecoin', 'flow', 'ftx_token', 'hedera', 'litecoin', 'maker', 'polkadot', 'polygon', 'quant', 'shiba_inu', 'solana', 'stellar', 'tether', 'tezos', 'the_sandbox', 'theta', 'tron', 'uniswap', 'unus_sed_leo', 'usd_coin_centre', 'vechain', 'wrapped_bitcoin', 'xrp', 'zcash']

# %%
df = pd.DataFrame(columns=["coin","symbol","link","whitepaper_link"])

# Create dataframe of coins with whitepaper link if available
for coin in top_currencies:
    req = requests.get(coin, headers)
    soup = BeautifulSoup(req.content, 'html.parser')
    symbol = soup.find("small",  attrs={"class": "nameSymbol"})
    name = symbol.parent.contents[0]
    whitepaper_tags = soup.find_all("a", attrs={"class": "link-button", "rel": "nofollow noopener"}, href=True)
    whitepaper_link = whitepaper_tags[-1]["href"] if len(whitepaper_tags) > 0 else ""
    df.loc[len(df.index)] = [name, symbol.text, coin, whitepaper_link if whitepaper_link and whitepaper_link.endswith(".pdf") else ""]
# Out:
#            coin symbol                                             link  \
# 0       Bitcoin    BTC    https://coinmarketcap.com/currencies/bitcoin/
# 1      Ethereum    ETH   https://coinmarketcap.com/currencies/ethereum/
# 2        Tether   USDT     https://coinmarketcap.com/currencies/tether/
# 3      USD Coin   USDC   https://coinmarketcap.com/currencies/usd-coin/
# 4           BNB    BNB        https://coinmarketcap.com/currencies/bnb/
# ..          ...    ...                                              ...
# 95         Holo    HOT       https://coinmarketcap.com/currencies/holo/
# 96         Qtum   QTUM       https://coinmarketcap.com/currencies/qtum/
# 97  XDC Network    XDC     https://coinmarketcap.com/currencies/xinfin/
# 98         Gala   GALA       https://coinmarketcap.com/currencies/gala/
# 99    Ravencoin    RVN  https://coinmarketcap.com/currencies/ravencoin/
#
#                                       whitepaper_link
# 0                     https://bitcoin.org/bitcoin.pdf
# 1
# 2   https://tether.to/wp-content/uploads/2016/06/T...
# 3   https://f.hubspotusercontent30.net/hubfs/93046...
# 4
# ..                                                ...
# 95
# 96  https://qtum.org/user/pages/01.home/Qtum%20whi...
# 97        https://xinfin.org/docs/whitepaper-tech.pdf
# 98
# 99
#
# [100 rows x 4 columns]

# %%
# download pdf if whitepaper not already downloaded
# for index, row in df.iterrows():
#     coin = row["coin"].lower().replace(" ","_")
#     if coin not in existing_coins: print(coin)
whitepaper_downloaded = []
for _, row in df.iterrows():
    name = row["coin"].lower().replace(" ", "_")
    if name not in existing_coins and row["whitepaper_link"]:
        try:
            response = requests.get(row["whitepaper_link"])
            with open("papers/" + str(name)+".pdf", 'wb') as pdf:
                pdf.write(response.content)
                pdf.close()
            whitepaper_downloaded.append(True)
        except:
            whitepaper_downloaded.append(False)
    elif name in existing_coins:
        whitepaper_downloaded.append(True)
    else:
        whitepaper_downloaded.append(False)

df["whitepaper_obtained"] = whitepaper_downloaded
# Out:
# bitcoin  exists
# ethereum  exists
# tether  exists
# usd_coin  downloaded
# bnb  exists
# xrp  exists
# cardano  not available
# binance_usd  not available
# solana  exists
# polkadot  exists
# dogecoin  exists
# avalanche  exists
# dai  exists
# polygon  exists
# shiba_inu  exists
# uniswap  exists
# tron  exists
# wrapped_bitcoin  exists
# ethereum_classic  not available
# unus_sed_leo  exists
# litecoin  exists
# near_protocol  not available
# chainlink  exists
# ftx_token  exists
# cronos  downloaded
# cosmos  exists
# stellar  exists
# flow  exists
# monero  downloaded
# bitcoin_cash  not available
# algorand  not available
# vechain  exists
# filecoin  exists
# apecoin  not available
# internet_computer  downloaded
# decentraland  exists
# hedera  exists
# tezos  exists
# the_sandbox  exists
# theta_network  downloaded
# axie_infinity  exists
# elrond  exists
# aave  exists
# quant  exists
# eos  exists
# trueusd  not available
# bitcoin_sv  not available
# zcash  exists
# okb  not available
# helium  not available
# maker  exists
# kucoin_token  downloaded
# fantom  not available
# the_graph  not available
# iota  downloaded
# thorchain  not available
# bittorrent-new  downloaded
# chiliz  not available
# ecash  not available
# klaytn  not available
# neo  not available
# lido_dao  downloaded
# usdd  downloaded
# curve_dao_token  not available
# neutrino_usd  not available
# basic_attention_token  downloaded
# huobi_token  not available
# stacks  downloaded
# waves  not available
# pancakeswap  not available
# enjin_coin  not available
# loopring  not available
# zilliqa  downloaded
# dash  not available
# pax_gold  not available
# celsius  not available
# mina  not available
# stepn  not available
# kava  not available
# bitcoin_gold  not available
# celo  not available
# kusama  not available
# nexo  not available
# decred  not available
# oasis_network  not available
# arweave  downloaded
# 1inch_network  not available
# convex_finance  not available
# ankr  not available
# nem  not available
# trust_wallet_token  not available
# gnosis  downloaded
# synthetix  not available
# compound  not available
# holo  not available
# qtum  downloaded
# xdc_network  downloaded
# gala  not available
# ravencoin  not available
#                      coin symbol  \
# 0                 Bitcoin    BTC
# 1                Ethereum    ETH
# 2                  Tether   USDT
# 3                USD Coin   USDC
# 4                     BNB    BNB
# 5                     XRP    XRP
# 6                 Cardano    ADA
# 7             Binance USD   BUSD
# 8                  Solana    SOL
# 9                Polkadot    DOT
# 10               Dogecoin   DOGE
# 11              Avalanche   AVAX
# 12                    Dai    DAI
# 13                Polygon  MATIC
# 14              Shiba Inu   SHIB
# 15                Uniswap    UNI
# 16                   TRON    TRX
# 17        Wrapped Bitcoin   WBTC
# 18       Ethereum Classic    ETC
# 19           UNUS SED LEO    LEO
# 20               Litecoin    LTC
# 21          NEAR Protocol   NEAR
# 22              Chainlink   LINK
# 23              FTX Token    FTT
# 24                 Cronos    CRO
# 25                 Cosmos   ATOM
# 26                Stellar    XLM
# 27                   Flow   FLOW
# 28                 Monero    XMR
# 29           Bitcoin Cash    BCH
# 30               Algorand   ALGO
# 31                VeChain    VET
# 32               Filecoin    FIL
# 33                ApeCoin    APE
# 34      Internet Computer    ICP
# 35           Decentraland   MANA
# 36                 Hedera   HBAR
# 37                  Tezos    XTZ
# 38            The Sandbox   SAND
# 39          Theta Network  THETA
# 40          Axie Infinity    AXS
# 41                 Elrond   EGLD
# 42                   Aave   AAVE
# 43                  Quant    QNT
# 44                    EOS    EOS
# 45                TrueUSD   TUSD
# 46             Bitcoin SV    BSV
# 47                  Zcash    ZEC
# 48                    OKB    OKB
# 49                 Helium    HNT
# 50                  Maker    MKR
# 51           KuCoin Token    KCS
# 52                 Fantom    FTM
# 53              The Graph    GRT
# 54                   IOTA  MIOTA
# 55              THORChain   RUNE
# 56         BitTorrent-New    BTT
# 57             Pax Dollar   USDP
# 58                 Chiliz    CHZ
# 59                  eCash    XEC
# 60                 Klaytn   KLAY
# 61                    Neo    NEO
# 62               Lido DAO    LDO
# 63                   USDD   USDD
# 64        Curve DAO Token    CRV
# 65           Neutrino USD   USDN
# 66  Basic Attention Token    BAT
# 67            Huobi Token     HT
# 68                 Stacks    STX
# 69                  Waves  WAVES
# 70            PancakeSwap   CAKE
# 71             Enjin Coin    ENJ
# 72               Loopring    LRC
# 73                Zilliqa    ZIL
# 74                   Dash   DASH
# 75               PAX Gold   PAXG
# 76                Celsius    CEL
# 77                   Mina   MINA
# 78                  STEPN    GMT
# 79                   Kava   KAVA
# 80           Bitcoin Gold    BTG
# 81                   Celo   CELO
# 82                 Kusama    KSM
# 83                   Nexo   NEXO
# 84                 Decred    DCR
# 85          Oasis Network   ROSE
# 86                Arweave     AR
# 87          1inch Network  1INCH
# 88         Convex Finance    CVX
# 89                   Ankr   ANKR
# 90                    NEM    XEM
# 91     Trust Wallet Token    TWT
# 92                 Gnosis    GNO
# 93              Synthetix    SNX
# 94               Compound   COMP
# 95                   Holo    HOT
# 96                   Qtum   QTUM
# 97            XDC Network    XDC
# 98                   Gala   GALA
# 99              Ravencoin    RVN
#
#                                                  link  \
# 0       https://coinmarketcap.com/currencies/bitcoin/
# 1      https://coinmarketcap.com/currencies/ethereum/
# 2        https://coinmarketcap.com/currencies/tether/
# 3      https://coinmarketcap.com/currencies/usd-coin/
# 4           https://coinmarketcap.com/currencies/bnb/
# 5           https://coinmarketcap.com/currencies/xrp/
# 6       https://coinmarketcap.com/currencies/cardano/
# 7   https://coinmarketcap.com/currencies/binance-usd/
# 8        https://coinmarketcap.com/currencies/solana/
# 9   https://coinmarketcap.com/currencies/polkadot-...
# 10     https://coinmarketcap.com/currencies/dogecoin/
# 11    https://coinmarketcap.com/currencies/avalanche/
# 12  https://coinmarketcap.com/currencies/multi-col...
# 13      https://coinmarketcap.com/currencies/polygon/
# 14    https://coinmarketcap.com/currencies/shiba-inu/
# 15      https://coinmarketcap.com/currencies/uniswap/
# 16         https://coinmarketcap.com/currencies/tron/
# 17  https://coinmarketcap.com/currencies/wrapped-b...
# 18  https://coinmarketcap.com/currencies/ethereum-...
# 19  https://coinmarketcap.com/currencies/unus-sed-...
# 20     https://coinmarketcap.com/currencies/litecoin/
# 21  https://coinmarketcap.com/currencies/near-prot...
# 22    https://coinmarketcap.com/currencies/chainlink/
# 23    https://coinmarketcap.com/currencies/ftx-token/
# 24       https://coinmarketcap.com/currencies/cronos/
# 25       https://coinmarketcap.com/currencies/cosmos/
# 26      https://coinmarketcap.com/currencies/stellar/
# 27         https://coinmarketcap.com/currencies/flow/
# 28       https://coinmarketcap.com/currencies/monero/
# 29  https://coinmarketcap.com/currencies/bitcoin-c...
# 30     https://coinmarketcap.com/currencies/algorand/
# 31      https://coinmarketcap.com/currencies/vechain/
# 32     https://coinmarketcap.com/currencies/filecoin/
# 33  https://coinmarketcap.com/currencies/apecoin-ape/
# 34  https://coinmarketcap.com/currencies/internet-...
# 35  https://coinmarketcap.com/currencies/decentral...
# 36       https://coinmarketcap.com/currencies/hedera/
# 37        https://coinmarketcap.com/currencies/tezos/
# 38  https://coinmarketcap.com/currencies/the-sandbox/
# 39  https://coinmarketcap.com/currencies/theta-net...
# 40  https://coinmarketcap.com/currencies/axie-infi...
# 41  https://coinmarketcap.com/currencies/elrond-egld/
# 42         https://coinmarketcap.com/currencies/aave/
# 43        https://coinmarketcap.com/currencies/quant/
# 44          https://coinmarketcap.com/currencies/eos/
# 45      https://coinmarketcap.com/currencies/trueusd/
# 46   https://coinmarketcap.com/currencies/bitcoin-sv/
# 47        https://coinmarketcap.com/currencies/zcash/
# 48          https://coinmarketcap.com/currencies/okb/
# 49       https://coinmarketcap.com/currencies/helium/
# 50        https://coinmarketcap.com/currencies/maker/
# 51  https://coinmarketcap.com/currencies/kucoin-to...
# 52       https://coinmarketcap.com/currencies/fantom/
# 53    https://coinmarketcap.com/currencies/the-graph/
# 54         https://coinmarketcap.com/currencies/iota/
# 55    https://coinmarketcap.com/currencies/thorchain/
# 56  https://coinmarketcap.com/currencies/bittorren...
# 57  https://coinmarketcap.com/currencies/paxos-sta...
# 58       https://coinmarketcap.com/currencies/chiliz/
# 59        https://coinmarketcap.com/currencies/ecash/
# 60       https://coinmarketcap.com/currencies/klaytn/
# 61          https://coinmarketcap.com/currencies/neo/
# 62     https://coinmarketcap.com/currencies/lido-dao/
# 63         https://coinmarketcap.com/currencies/usdd/
# 64  https://coinmarketcap.com/currencies/curve-dao...
# 65  https://coinmarketcap.com/currencies/neutrino-...
# 66  https://coinmarketcap.com/currencies/basic-att...
# 67  https://coinmarketcap.com/currencies/huobi-token/
# 68       https://coinmarketcap.com/currencies/stacks/
# 69        https://coinmarketcap.com/currencies/waves/
# 70  https://coinmarketcap.com/currencies/pancakeswap/
# 71   https://coinmarketcap.com/currencies/enjin-coin/
# 72     https://coinmarketcap.com/currencies/loopring/
# 73      https://coinmarketcap.com/currencies/zilliqa/
# 74         https://coinmarketcap.com/currencies/dash/
# 75     https://coinmarketcap.com/currencies/pax-gold/
# 76      https://coinmarketcap.com/currencies/celsius/
# 77         https://coinmarketcap.com/currencies/mina/
# 78  https://coinmarketcap.com/currencies/green-met...
# 79         https://coinmarketcap.com/currencies/kava/
# 80  https://coinmarketcap.com/currencies/bitcoin-g...
# 81         https://coinmarketcap.com/currencies/celo/
# 82       https://coinmarketcap.com/currencies/kusama/
# 83         https://coinmarketcap.com/currencies/nexo/
# 84       https://coinmarketcap.com/currencies/decred/
# 85  https://coinmarketcap.com/currencies/oasis-net...
# 86      https://coinmarketcap.com/currencies/arweave/
# 87        https://coinmarketcap.com/currencies/1inch/
# 88  https://coinmarketcap.com/currencies/convex-fi...
# 89         https://coinmarketcap.com/currencies/ankr/
# 90          https://coinmarketcap.com/currencies/nem/
# 91  https://coinmarketcap.com/currencies/trust-wal...
# 92   https://coinmarketcap.com/currencies/gnosis-gno/
# 93  https://coinmarketcap.com/currencies/synthetix...
# 94     https://coinmarketcap.com/currencies/compound/
# 95         https://coinmarketcap.com/currencies/holo/
# 96         https://coinmarketcap.com/currencies/qtum/
# 97       https://coinmarketcap.com/currencies/xinfin/
# 98         https://coinmarketcap.com/currencies/gala/
# 99    https://coinmarketcap.com/currencies/ravencoin/
#
#                                       whitepaper_link  whitepaper_obtained
# 0                     https://bitcoin.org/bitcoin.pdf                 True
# 1                                                                     True
# 2   https://tether.to/wp-content/uploads/2016/06/T...                 True
# 3   https://f.hubspotusercontent30.net/hubfs/93046...                 True
# 4                                                                     True
# 5   https://ripple.com/files/ripple_consensus_whit...                 True
# 6                                                                    False
# 7                                                                    False
# 8            https://solana.com/solana-whitepaper.pdf                 True
# 9          https://polkadot.network/PolkaDotPaper.pdf                 True
# 10                                                                    True
# 11                                                                    True
# 12                                                                    True
# 13                                                                    True
# 14  https://github.com/shytoshikusama/woofwoofpape...                 True
# 15                                                                    True
# 16                                                                    True
# 17  https://www.wbtc.network/assets/wrapped-tokens...                 True
# 18                                                                   False
# 19            https://www.bitfinex.com/wp-2019-05.pdf                 True
# 20                                                                    True
# 21                                                                   False
# 22                                                                    True
# 23                                                                    True
# 24  https://www.crypto.com/images/chain_whitepaper...                 True
# 25                                                                    True
# 26  https://www.stellar.org/papers/stellar-consens...                 True
# 27                                                                    True
# 28  https://github.com/monero-project/research-lab...                 True
# 29                                                                   False
# 30                                                                   False
# 31                                                                    True
# 32                                                                    True
# 33                                                                   False
# 34                 https://dfinity.org/whitepaper.pdf                 True
# 35            https://decentraland.org/whitepaper.pdf                 True
# 36                                                                    True
# 37                   https://tezos.com/whitepaper.pdf                 True
# 38  http://www.sandbox.game/The_Sandbox_Whitepaper...                 True
# 39  https://s3.us-east-2.amazonaws.com/assets.thet...                 True
# 40                                                                    True
# 41  https://elrond.com/assets/files/elrond-whitepa...                 True
# 42  https://github.com/aave/aave-protocol/blob/mas...                 True
# 43                                                                    True
# 44                                                                    True
# 45                                                                   False
# 46                                                                   False
# 47  https://github.com/zcash/zips/blob/master/prot...                 True
# 48                                                                   False
# 49                                                                   False
# 50                                                                    True
# 51      https://www.kcs.foundation/kcs-whitepaper.pdf                 True
# 52                                                                   False
# 53                                                                   False
# 54               https://iota.org/IOTA_Whitepaper.pdf                 True
# 55                                                                   False
# 56  https://www.bittorrent.com/btt/btt-docs/BitTor...                 True
# 57          https://standard.paxos.com/whitepaper.pdf                False
# 58                                                                   False
# 59                                                                   False
# 60                                                                   False
# 61                                                                   False
# 62  https://lido.fi/static/Lido:Ethereum-Liquid-St...                 True
# 63                   https://usdd.network/USDD-en.pdf                 True
# 64                                                                   False
# 65                                                                   False
# 66  https://basicattentiontoken.org/BasicAttention...                 True
# 67                                                                   False
# 68  https://gaia.blockstack.org/hub/1AxyPunHHAHiEf...                 True
# 69                                                                   False
# 70                                                                   False
# 71                                                                   False
# 72                                                                   False
# 73            https://docs.zilliqa.com/whitepaper.pdf                 True
# 74                                                                   False
# 75                                                                   False
# 76                                                                   False
# 77                                                                   False
# 78                                                                   False
# 79                                                                   False
# 80                                                                   False
# 81                                                                   False
# 82                                                                   False
# 83                                                                   False
# 84                                                                   False
# 85                                                                   False
# 86  https://www.arweave.org/files/arweave-lightpap...                 True
# 87                                                                   False
# 88                                                                   False
# 89                                                                   False
# 90                                                                   False
# 91                                                                   False
# 92  https://github.com/gnosis/research/blob/master...                 True
# 93                                                                   False
# 94                                                                   False
# 95                                                                   False
# 96  https://qtum.org/user/pages/01.home/Qtum%20whi...                 True
# 97        https://xinfin.org/docs/whitepaper-tech.pdf                 True
# 98                                                                   False
# 99                                                                   False

# %%
#import PyPDF2
from os import listdir
from io import StringIO

from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser

pdf_path = "./papers"
pdfs = [f for f in listdir(pdf_path) if f.endswith(".pdf")]

failed_conversions = []

for pdf in pdfs:
    output_string = StringIO()
    name = pdf.split(".")[0]
    try:
        with open("./papers/" + name + ".pdf", 'rb') as in_file:
            parser = PDFParser(in_file)
            doc = PDFDocument(parser)
            rsrcmgr = PDFResourceManager()
            device = TextConverter(rsrcmgr, output_string, laparams=LAParams())
            interpreter = PDFPageInterpreter(rsrcmgr, device)
            for page in PDFPage.create_pages(doc):
                interpreter.process_page(page)
            in_file.close()
        with open("./text/" + name + ".txt","w") as out_file:
            out_file.writelines(output_string.getvalue())
            out_file.close()
        print(pdf + " finished")
    except:
        failed_conversions.append(pdf)
        print(pdf + " pls bro no work")



# with open("./papers/qtum.pdf", "rb") as f:
#     try:
#         pdfreader=PyPDF2.PdfFileReader(f)
#         x=pdfreader.numPages
#         pageobj=pdfreader.getPage(1)
#         text=pageobj.extractText()
#         #print(pdfreader.numPages)
#         print(text)
#         f.close()
#     except:
#         print("wtf man cmon",pdf)

#print(pdfs)
# for pdf in sorted(pdfs):
#     with open("./papers/" + pdf, "rb") as f:
#         try:
#             pdfreader=PyPDF2.PdfFileReader(f)
#             x=pdfreader.numPages
#             pageobj=pdfreader.getPage(0)
#             text=pageobj.extractText()
#             #print(pdfreader.numPages)
#             print(text)
#             f.close()
#         except:
#             print("wtf man cmon",pdf)
# Out:
# qtum.pdf finished
# bittorrent-new.pdf finished
# stacks.pdf finished
# dash.pdf finished
# theta_network.pdf finished
# oasis_network.pdf finished
# nexo.pdf finished
# THORChain-Whitepaper-May2020.pdf finished
# basic_attention_token.pdf finished
# fantom.pdf finished
# chiliz.pdf finished
# gala.pdf finished
# tusd.pdf finished
# klaytn.pdf finished
# neo.pdf finished
# usdd.pdf finished
# nem.pdf finished
# ethereum_classic.pdf finished
# usd_coin.pdf finished
# cronos.pdf pls bro no work
# algorand.pdf finished
# enjin_coin.pdf finished
# arweave.pdf finished
# mina.pdf finished
# the-graph-whitepaper.pdf finished
# pax_dollar.pdf finished
# decred.pdf finished
# huobi_token.pdf finished
# convex_finance.pdf finished
# curve_dao_token.pdf finished
# ravencoin.pdf finished
# internet_computer.pdf finished
# zilliqa.pdf finished
# ankr.pdf finished
# holo.pdf finished
# pax_gold.pdf finished
# waves.pdf finished
# bitcoin_gold.pdf finished
# near_protocol.pdf finished
# lido_dao.pdf finished
# loopring.pdf finished
# xdc_network.pdf finished
# trust_wallet_token.pdf finished
# celsius.pdf finished
# iota.pdf pls bro no work
# compound.pdf finished
# kucoin_token.pdf finished
# kava.pdf finished
# helium.pdf finished
# 1inch_network.pdf finished
# gnosis.pdf pls bro no work
# synthetix.pdf finished
# ape_coin.pdf finished
# monero.pdf pls bro no work
